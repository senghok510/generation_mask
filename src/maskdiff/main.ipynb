# %%
! pip install gdown

# %%
import os
os.getcwd()

# %%
# !gdown --id 17-FCstm8Fz3bDzFgTmOWHa_c39lTR_1P -O ../../data/CMFD.zip

# %%
from datasets import load_dataset

# %%
import numpy as np
import transformers
